# %% [markdown]
# ## ASSIGNMENT GenAI – Prompt Templates using LangChain

# %%
# !pip install langchain langchain-core --upgrade
# Out:
# Requirement already satisfied: langchain in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (1.3.2)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (0.0.12)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: anyio in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.7.0)
# Requirement already satisfied: certifi in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jitendra khandelwal\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# #### Task 1: Replace Hardcoded Prompts

# %%
# # Task 1: Replace hardcoded prompt using PromptTemplate
template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)

# test
print(template.format(topic="Artificial Intelligence"))

# %% [markdown]
# #### TASK 2 — Multi Input Prompt

# %%
multi_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# test cases
print(multi_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_template.format(topic="Deep Learning", audience="engineers", tone="technical"))

# %% [markdown]
# #### TASK 3 — Prompt Variations

# %%
#  Create multiple prompt templates

teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

# run for Machine Learning
topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))

# %% [markdown]
# #### TASK 4 — ChatPromptTemplate

# %%
roles = ["teacher", "interviewer", "motivator"]

for role in roles:
    messages = chat_template.format_messages(
        role=role,
        topic="Neural Networks"
    )
    
    print(f"\nRole: {role}")
    for msg in messages:
        print(msg)

# %% [markdown]
# #### TASK 5 — Input Validation

# %%
# Input validation function

def validate_inputs(audience, tone):

    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        print("Invalid audience → using default 'beginner'")
        audience = "beginner"

    if tone not in valid_tone:
        print("Invalid tone → using default 'formal'")
        tone = "formal"

    return audience, tone

# %% [markdown]
# #### TASK 6 — Prompt Generator App

# %%
# Task 6: Prompt Generator App 

def generate_prompt(topic, audience, tone, style):

    audience, tone = validate_inputs(audience, tone)

    base_template = PromptTemplate(
        input_variables=["topic", "audience", "tone", "style"],
        template="Explain {topic} for {audience} in a {tone} {style} style"
    )

    return base_template.format(
        topic=topic,
        audience=audience,
        tone=tone,
        style=style
    )


# test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))

# %% [markdown]
# #### TASK 7 — Reusability Test

# %%
reuse_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = ["AI", "Python", "ML", "DL", "NLP"]

for t in topics:
    print(reuse_template.format(topic=t))
